# %% [markdown]
# ## FCN

# %% [markdown]
# ### 方法一

# %%
import torch
import torchvision
from torch.utils.data import DataLoader
import torch.nn as nn
from torch.nn import functional as F
import torchvision.transforms as transforms
import torch.optim as optim
import matplotlib.pyplot as plt
import os
import pickle
from PIL import Image
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
# 定义 FCN 模型

class FCN(nn.Module):
    def __init__(self, num_classes=4):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2)
        self.gap = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Linear(512, num_classes)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = self.pool(torch.relu(self.conv3(x)))
        x = self.pool(torch.relu(self.conv4(x)))
        x = self.pool(torch.relu(self.conv5(x)))
        x = self.gap(x)  # Global Average Pool全局平均池化
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

# %% [markdown]
# ### 方法二

# %%
# Define the FCN model
'''
class FCN(nn.Module):
  def __init__(self, num_classes=4):
    super(FCN, self).__init__()
    self.conv1 = nn.Conv2d(3, 32, 3, padding=1)
    self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
    self.conv3 = nn.Conv2d(64, 128, 3, padding=1)
    self.conv4 = nn.Conv2d(128, 256, 3, padding=1)
    self.conv5 = nn.Conv2d(256, 512, 3, padding=1)
    self.conv6 = nn.Conv2d(512, 1024, 3, padding=1)
    self.conv7 = nn.Conv2d(1024, 2048, 3, padding=1)
    self.conv8 = nn.Conv2d(2048, num_classes, 1)

  def forward(self, x):
    x = nn.functional.relu(self.conv1(x))
    x = nn.functional.relu(self.conv2(x))
    x = nn.functional.relu(self.conv3(x))
    x = nn.functional.relu(self.conv4(x))
    x = nn.functional.relu(self.conv5(x))
    x = nn.functional.relu(self.conv6(x))
    x = nn.functional.relu(self.conv7(x))
    x = self.conv8(x)
    return x
'''
# Out:
# '\nclass FCN(nn.Module):\n  def __init__(self, num_classes=4):\n    super(FCN, self).__init__()\n    self.conv1 = nn.Conv2d(3, 32, 3, padding=1)\n    self.conv2 = nn.Conv2d(32, 64, 3, padding=1)\n    self.conv3 = nn.Conv2d(64, 128, 3, padding=1)\n    self.conv4 = nn.Conv2d(128, 256, 3, padding=1)\n    self.conv5 = nn.Conv2d(256, 512, 3, padding=1)\n    self.conv6 = nn.Conv2d(512, 1024, 3, padding=1)\n    self.conv7 = nn.Conv2d(1024, 2048, 3, padding=1)\n    self.conv8 = nn.Conv2d(2048, num_classes, 1)\n\n  def forward(self, x):\n    x = nn.functional.relu(self.conv1(x))\n    x = nn.functional.relu(self.conv2(x))\n    x = nn.functional.relu(self.conv3(x))\n    x = nn.functional.relu(self.conv4(x))\n    x = nn.functional.relu(self.conv5(x))\n    x = nn.functional.relu(self.conv6(x))\n    x = nn.functional.relu(self.conv7(x))\n    x = self.conv8(x)\n    return x\n'

# %%
def train_epoch(net, data_loader, device):

    net.train() # 指定当前为训练模式
    train_batch_num = len(data_loader) # 记录共有多少个batch
    total_loss = 0 # 记录Loss
    correct = 0  # 记录共有多少个样本被正确分类
    sample_num = 0 # 记录样本总数

    # 遍历每个batch进行训练
    for batch_idx, (data, target) in enumerate(data_loader):
        # 将图片放入指定的device中
        data = data.to(device).float()
        # 将图片标签放入指定的device中
        target = target.to(device).long()
        # 将当前梯度清零
        optimizer.zero_grad()
        # 使用模型计算出结果
        output = net(data)
        # 计算损失
        loss = criterion(output, target)
        # 进行反向传播
        loss.backward()
        optimizer.step()
        # 累加Loss
        total_loss += loss.item()
        # 找出每个样本值最大的idx，即代表预测此图片属于哪个类别
        prediction = torch.argmax(output, 1)
        # 统计预测正确的类别数量
        correct += (prediction == target).sum().item()
        # 累加当前的样本总数
        sample_num += len(prediction)
    # 计算平均的loss与准确率
    loss = total_loss / train_batch_num
    acc = correct / sample_num
    return loss, acc

# %%
def test_epoch(net, data_loader, device):
    net.eval() # 指定当前模式为测试模式
    test_batch_num = len(data_loader)
    total_loss = 0
    correct = 0
    sample_num = 0
    # 指定不进行梯度变化
    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(data_loader):
            data = data.to(device).float()
            target = target.to(device).long()
            output = net(data)
            loss = criterion(output, target)
            total_loss += loss.item()
            prediction = torch.argmax(output, 1)
            correct += (prediction == target).sum().item()
            sample_num += len(prediction)
    loss = total_loss / test_batch_num
    acc = correct / sample_num
    return loss, acc

# %%
# 创建自己的类：MyDataset,这个类是继承的torch.utils.data.Dataset
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, root, datatxt, transform=None, target_transform=None):  # 初始化一些需要传入的参数

        fh = open(root + datatxt, 'r')  # 按照传入的路径和txt文本参数，打开这个文本，并读取内容
        imgs = []  # 创建一个名为img的空列表，一会儿用来装东西
        for line in fh:  # 按行循环txt文本中的内容
            line = line.rstrip()       # 删除 本行string 字符串末尾的指定字符，这个方法的详细介绍自己查询python
            words = line.split()  # 通过指定分隔符对字符串进行切片，默认为所有的空字符，包括空格、换行、制表符等
            # 把txt里的内容读入imgs列表保存，具体是words几要看txt内容而定
            imgs.append((words[0]+' '+words[1], int(words[2])))
            # 很显然，根据我刚才截图所示txt的内容，words[0]是图片信息，words[1]是label
        self.imgs = imgs
        self.transform = transform
        self.target_transform = target_transform

    def __getitem__(self, index):  # 这个方法是必须要有的，用于按照索引读取每个元素的具体内容
        # fn是图片path #fn和label分别获得imgs[index]也即是刚才每行中word[0]和word[1]的信息
        fn, label = self.imgs[index]
        # 按照path读入图片from PIL import Image # 按照路径读取图片
        img = Image.open(rootMirror+fn).convert('RGB')

        if self.transform is not None:
            img = self.transform(img)  # 是否进行transform
        return img, label  # return很关键，return回哪些内容，那么我们在训练时循环读取每个batch时，就能获得哪些内容

    def __len__(self):  # 这个函数也必须要写，它返回的是数据集的长度，也就是多少张图片，要和loader的长度作区分
        return len(self.imgs)


# 根据自己定义的MyDataset来创建数据集！注意是数据集！而不是loader迭代器
root = 'D:\\CS第四学期课程\\毕业设计\\代码\\data\\'
rootMirror = 'D:\\CS第四学期课程\\毕业设计\\代码\\data\\backup\\smaller32\\'
train_data = MyDataset(root, datatxt='train.txt',
                       transform=transforms.ToTensor())
test_data = MyDataset(root, datatxt='test.txt',
                      transform=transforms.ToTensor())
print("妥了")

classes = ('1', '2', '3', '4')
num_classes = 16  # 共4类
epochs = 100  # 训练多少轮
lr = 0.001  # 学习率
batch_size = 4  # batch大小
# device = torch.device("cuda:0") # 指定device为0号GPU,若使用cpu则填写 "cpu"
device = torch.device("cpu")
# 生成dataloader
my_trainloader = torch.utils.data.DataLoader(
    train_data, batch_size=batch_size, shuffle=True, num_workers=0)
my_testloader = torch.utils.data.DataLoader(
    test_data, batch_size=batch_size, shuffle=True, num_workers=0)
# Out:
# 妥了

# %%
# 初始化模型
net = FCN(4).to(device)
# 使用多元交叉熵损失
criterion = nn.CrossEntropyLoss()
# 使用Adam优化器
optimizer = optim.Adam(net.parameters(), lr=lr)

# %%
# 存储每一个epoch的loss与acc的变化，便于后面可视化
train_loss_list = []
train_acc_list = []
test_loss_list = []
test_acc_list = []

# 进行训练
for epoch in range(epochs):
    # 在训练集上训练
    train_loss, train_acc = train_epoch(net, data_loader=my_trainloader, device=device)
    # 在测试集上验证
    test_loss, test_acc = test_epoch(net, data_loader=my_testloader, device=device)
    # 保存各个指标
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)
    test_loss_list.append(test_loss)
    test_acc_list.append(test_acc)
    print(f"epoch:{epoch}\t train_loss:{train_loss:.4f} \t"
          f"train_acc:{train_acc} \t"
          f"test_loss:{test_loss:.4f} \t test_acc:{test_acc}")
# Out:
# epoch:0	 train_loss:0.6330 	train_acc:0.7381776239907728 	test_loss:0.3122 	 test_acc:0.865047233468286
# epoch:1	 train_loss:0.2502 	train_acc:0.8872549019607843 	test_loss:0.2661 	 test_acc:0.893387314439946
# epoch:2	 train_loss:0.2078 	train_acc:0.9132064590542099 	test_loss:0.2111 	 test_acc:0.9163292847503374
# epoch:3	 train_loss:0.1707 	train_acc:0.9253171856978085 	test_loss:0.1822 	 test_acc:0.9163292847503374
# epoch:4	 train_loss:0.1647 	train_acc:0.932237600922722 	test_loss:0.2180 	 test_acc:0.9136302294197031
# epoch:5	 train_loss:0.1521 	train_acc:0.9348327566320646 	test_loss:0.1913 	 test_acc:0.9163292847503374
# epoch:6	 train_loss:0.1426 	train_acc:0.9391580161476355 	test_loss:0.2226 	 test_acc:0.9149797570850202
# epoch:7	 train_loss:0.1269 	train_acc:0.9455017301038062 	test_loss:0.1873 	 test_acc:0.9298245614035088
# epoch:8	 train_loss:0.1307 	train_acc:0.9478085351787774 	test_loss:0.1520 	 test_acc:0.9257759784075573
# epoch:9	 train_loss:0.1148 	train_acc:0.9504036908881199 	test_loss:0.1595 	 test_acc:0.9338731443994602
# epoch:10	 train_loss:0.1037 	train_acc:0.9561707035755479 	test_loss:0.1205 	 test_acc:0.9406207827260459
# epoch:11	 train_loss:0.0887 	train_acc:0.9602076124567474 	test_loss:0.1833 	 test_acc:0.9325236167341431
# epoch:12	 train_loss:0.0919 	train_acc:0.9659746251441753 	test_loss:0.2338 	 test_acc:0.9190283400809717
# epoch:13	 train_loss:0.0874 	train_acc:0.9688581314878892 	test_loss:0.1498 	 test_acc:0.9446693657219973
# epoch:14	 train_loss:0.0710 	train_acc:0.970876585928489 	test_loss:0.2785 	 test_acc:0.9203778677462888
# epoch:15	 train_loss:0.0594 	train_acc:0.9789504036908881 	test_loss:0.2641 	 test_acc:0.9352226720647774
# epoch:16	 train_loss:0.0836 	train_acc:0.970876585928489 	test_loss:0.1908 	 test_acc:0.941970310391363
# epoch:17	 train_loss:0.0676 	train_acc:0.9749134948096886 	test_loss:0.1997 	 test_acc:0.9365721997300944
# epoch:18	 train_loss:0.0864 	train_acc:0.9717416378316033 	test_loss:0.1755 	 test_acc:0.9446693657219973
# epoch:19	 train_loss:0.0468 	train_acc:0.9832756632064591 	test_loss:0.1743 	 test_acc:0.9433198380566802
# epoch:20	 train_loss:0.0586 	train_acc:0.9772202998846597 	test_loss:0.1700 	 test_acc:0.941970310391363
# epoch:21	 train_loss:0.0622 	train_acc:0.9789504036908881 	test_loss:0.2131 	 test_acc:0.9500674763832658
# epoch:22	 train_loss:0.0503 	train_acc:0.9821222606689735 	test_loss:0.1949 	 test_acc:0.9460188933873145
# epoch:23	 train_loss:0.0667 	train_acc:0.9772202998846597 	test_loss:0.1900 	 test_acc:0.941970310391363
# epoch:24	 train_loss:0.0429 	train_acc:0.9855824682814303 	test_loss:0.2105 	 test_acc:0.9568151147098516
# epoch:25	 train_loss:0.0511 	train_acc:0.9821222606689735 	test_loss:0.2231 	 test_acc:0.9460188933873145
# epoch:26	 train_loss:0.0462 	train_acc:0.984717416378316 	test_loss:0.2433 	 test_acc:0.9433198380566802
# epoch:27	 train_loss:0.0623 	train_acc:0.9812572087658593 	test_loss:0.1926 	 test_acc:0.9433198380566802
# epoch:28	 train_loss:0.0423 	train_acc:0.9841407151095732 	test_loss:0.1515 	 test_acc:0.9527665317139001
# epoch:29	 train_loss:0.0384 	train_acc:0.9867358708189158 	test_loss:0.2723 	 test_acc:0.941970310391363
# epoch:30	 train_loss:0.0472 	train_acc:0.9829873125720877 	test_loss:0.2269 	 test_acc:0.9500674763832658
# epoch:31	 train_loss:0.0436 	train_acc:0.9867358708189158 	test_loss:0.2398 	 test_acc:0.9365721997300944
# epoch:32	 train_loss:0.0410 	train_acc:0.9864475201845444 	test_loss:0.1889 	 test_acc:0.9473684210526315
# epoch:33	 train_loss:0.0389 	train_acc:0.9844290657439446 	test_loss:0.1541 	 test_acc:0.9554655870445344
# epoch:34	 train_loss:0.0455 	train_acc:0.9852941176470589 	test_loss:0.2117 	 test_acc:0.9487179487179487
# epoch:35	 train_loss:0.0235 	train_acc:0.9913494809688581 	test_loss:0.2101 	 test_acc:0.9406207827260459
# epoch:36	 train_loss:0.0444 	train_acc:0.9835640138408305 	test_loss:0.2414 	 test_acc:0.9379217273954116
# epoch:37	 train_loss:0.0748 	train_acc:0.9803921568627451 	test_loss:0.2038 	 test_acc:0.9473684210526315
# epoch:38	 train_loss:0.0224 	train_acc:0.9925028835063437 	test_loss:0.2791 	 test_acc:0.9500674763832658
# epoch:39	 train_loss:0.0341 	train_acc:0.9896193771626297 	test_loss:0.5066 	 test_acc:0.9379217273954116
# epoch:40	 train_loss:0.0340 	train_acc:0.9887543252595156 	test_loss:0.3629 	 test_acc:0.9527665317139001
# epoch:41	 train_loss:0.0271 	train_acc:0.9910611303344867 	test_loss:0.4536 	 test_acc:0.9311740890688259
# epoch:42	 train_loss:0.0477 	train_acc:0.9858708189158016 	test_loss:0.4706 	 test_acc:0.9352226720647774
# epoch:43	 train_loss:0.0197 	train_acc:0.9936562860438293 	test_loss:0.2334 	 test_acc:0.9554655870445344
# epoch:44	 train_loss:0.0303 	train_acc:0.9901960784313726 	test_loss:0.2924 	 test_acc:0.9568151147098516
# epoch:45	 train_loss:0.0398 	train_acc:0.9884659746251442 	test_loss:0.2499 	 test_acc:0.9460188933873145
# epoch:46	 train_loss:0.0393 	train_acc:0.989042675893887 	test_loss:0.2180 	 test_acc:0.9581646423751687
# epoch:47	 train_loss:0.0263 	train_acc:0.9922145328719724 	test_loss:0.2059 	 test_acc:0.9649122807017544
# epoch:48	 train_loss:0.0601 	train_acc:0.9878892733564014 	test_loss:0.4169 	 test_acc:0.9055330634278003
# epoch:49	 train_loss:0.0418 	train_acc:0.9867358708189158 	test_loss:0.2847 	 test_acc:0.9487179487179487
# epoch:50	 train_loss:0.0153 	train_acc:0.994232987312572 	test_loss:0.2325 	 test_acc:0.9649122807017544
# epoch:51	 train_loss:0.0177 	train_acc:0.9939446366782007 	test_loss:0.3058 	 test_acc:0.9473684210526315
# epoch:52	 train_loss:0.0176 	train_acc:0.994232987312572 	test_loss:0.3313 	 test_acc:0.9487179487179487
# epoch:53	 train_loss:0.0491 	train_acc:0.9881776239907728 	test_loss:0.3588 	 test_acc:0.9338731443994602
# epoch:54	 train_loss:0.0227 	train_acc:0.9936562860438293 	test_loss:0.2458 	 test_acc:0.9500674763832658
# epoch:55	 train_loss:0.0097 	train_acc:0.9974048442906575 	test_loss:0.4450 	 test_acc:0.9230769230769231
# epoch:56	 train_loss:0.0262 	train_acc:0.9907727797001153 	test_loss:0.5456 	 test_acc:0.921727395411606
# epoch:57	 train_loss:0.0299 	train_acc:0.9887543252595156 	test_loss:0.2889 	 test_acc:0.9595141700404858
# epoch:58	 train_loss:0.0399 	train_acc:0.9901960784313726 	test_loss:0.3484 	 test_acc:0.9433198380566802
# epoch:59	 train_loss:0.0336 	train_acc:0.990484429065744 	test_loss:0.4202 	 test_acc:0.9163292847503374
# epoch:60	 train_loss:0.0108 	train_acc:0.9968281430219147 	test_loss:0.4037 	 test_acc:0.9500674763832658
# epoch:61	 train_loss:0.0183 	train_acc:0.994232987312572 	test_loss:0.5972 	 test_acc:0.9271255060728745
# epoch:62	 train_loss:0.0319 	train_acc:0.98760092272203 	test_loss:0.3002 	 test_acc:0.9622132253711201
# epoch:63	 train_loss:0.0068 	train_acc:0.9965397923875432 	test_loss:0.3662 	 test_acc:0.9581646423751687
# epoch:64	 train_loss:0.0045 	train_acc:0.9976931949250288 	test_loss:0.5005 	 test_acc:0.9595141700404858
# epoch:65	 train_loss:0.0033 	train_acc:0.9991349480968859 	test_loss:0.5443 	 test_acc:0.941970310391363
# epoch:66	 train_loss:0.0876 	train_acc:0.9803921568627451 	test_loss:0.3740 	 test_acc:0.9554655870445344
# epoch:67	 train_loss:0.0020 	train_acc:0.9997116493656286 	test_loss:0.4076 	 test_acc:0.9581646423751687
# epoch:68	 train_loss:0.0249 	train_acc:0.9936562860438293 	test_loss:0.4526 	 test_acc:0.941970310391363
# epoch:69	 train_loss:0.0336 	train_acc:0.9925028835063437 	test_loss:0.2872 	 test_acc:0.9473684210526315
# epoch:70	 train_loss:0.0107 	train_acc:0.9959630911188004 	test_loss:0.2281 	 test_acc:0.9595141700404858
# epoch:71	 train_loss:0.0009 	train_acc:1.0 	test_loss:0.2754 	 test_acc:0.9608636977058029
# epoch:72	 train_loss:0.0028 	train_acc:0.998558246828143 	test_loss:0.3713 	 test_acc:0.9500674763832658
# epoch:73	 train_loss:0.0745 	train_acc:0.984717416378316 	test_loss:0.2849 	 test_acc:0.9446693657219973
# epoch:74	 train_loss:0.0300 	train_acc:0.9916378316032295 	test_loss:0.2520 	 test_acc:0.951417004048583
# epoch:75	 train_loss:0.0037 	train_acc:0.9982698961937716 	test_loss:0.2772 	 test_acc:0.9581646423751687
# epoch:76	 train_loss:0.0097 	train_acc:0.9979815455594002 	test_loss:0.9245 	 test_acc:0.8704453441295547
# epoch:77	 train_loss:0.0336 	train_acc:0.989042675893887 	test_loss:0.3984 	 test_acc:0.9446693657219973
# epoch:78	 train_loss:0.0280 	train_acc:0.994232987312572 	test_loss:0.3436 	 test_acc:0.941970310391363
# epoch:79	 train_loss:0.0180 	train_acc:0.9922145328719724 	test_loss:0.4078 	 test_acc:0.941970310391363
# epoch:80	 train_loss:0.0061 	train_acc:0.998558246828143 	test_loss:0.3870 	 test_acc:0.9527665317139001
# epoch:81	 train_loss:0.0005 	train_acc:1.0 	test_loss:0.4259 	 test_acc:0.9554655870445344
# epoch:82	 train_loss:0.0004 	train_acc:1.0 	test_loss:0.4405 	 test_acc:0.9554655870445344
# epoch:83	 train_loss:0.0001 	train_acc:1.0 	test_loss:0.4660 	 test_acc:0.9581646423751687
# epoch:84	 train_loss:0.0001 	train_acc:1.0 	test_loss:0.4431 	 test_acc:0.9581646423751687
# epoch:85	 train_loss:0.1040 	train_acc:0.9801038062283737 	test_loss:0.3218 	 test_acc:0.9392712550607287
# epoch:86	 train_loss:0.0092 	train_acc:0.9982698961937716 	test_loss:0.3396 	 test_acc:0.9500674763832658
# epoch:87	 train_loss:0.0077 	train_acc:0.998558246828143 	test_loss:0.2927 	 test_acc:0.9635627530364372
# epoch:88	 train_loss:0.0025 	train_acc:0.9991349480968859 	test_loss:0.4433 	 test_acc:0.9433198380566802
# epoch:89	 train_loss:0.0342 	train_acc:0.9910611303344867 	test_loss:0.6824 	 test_acc:0.9500674763832658
# epoch:90	 train_loss:0.0029 	train_acc:0.9991349480968859 	test_loss:0.7602 	 test_acc:0.9325236167341431
# epoch:91	 train_loss:0.0312 	train_acc:0.9927912341407151 	test_loss:0.6075 	 test_acc:0.9406207827260459
# epoch:92	 train_loss:0.0502 	train_acc:0.9910611303344867 	test_loss:0.4202 	 test_acc:0.9527665317139001
# epoch:93	 train_loss:0.0031 	train_acc:0.9988465974625144 	test_loss:0.3800 	 test_acc:0.9581646423751687
# epoch:94	 train_loss:0.0002 	train_acc:1.0 	test_loss:0.3939 	 test_acc:0.9595141700404858
# epoch:95	 train_loss:0.0001 	train_acc:1.0 	test_loss:0.4131 	 test_acc:0.9622132253711201
# epoch:96	 train_loss:0.0000 	train_acc:1.0 	test_loss:0.4336 	 test_acc:0.9581646423751687
# epoch:97	 train_loss:0.0000 	train_acc:1.0 	test_loss:0.4531 	 test_acc:0.9595141700404858
# epoch:98	 train_loss:0.0000 	train_acc:1.0 	test_loss:0.4784 	 test_acc:0.9595141700404858
# epoch:99	 train_loss:0.0000 	train_acc:1.0 	test_loss:0.4837 	 test_acc:0.9595141700404858

# %%
res = [train_loss_list, train_acc_list, test_loss_list,test_acc_list]

# %%
with open('FCN.pkl', 'wb') as f:
    pickle.dump(res, f)

# %%
plt.figure(figsize=(10, 6))
train, = plt.plot(train_loss_list,'.-',label='train_loss')
test, = plt.plot(test_loss_list,'.-',label='test_loss')
plt.title("Loss",fontsize=14)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend([train,test],["train_loss", "test_loss"],loc='upper right')
plt.show()

# %%
plt.figure(figsize=(10, 6))
train, = plt.plot(train_acc_list,'.-',label='train_acc')
test, = plt.plot(test_acc_list,'.-',label='test_acc')
plt.title("acc",fontsize=14)
plt.xlabel('epoch')
plt.ylabel('acc')
plt.legend([train,test],["train_acc", "test_acc"],loc='upper left')
plt.show()

# %%
max(test_acc_list)
# Out:
# 0.9649122807017544
